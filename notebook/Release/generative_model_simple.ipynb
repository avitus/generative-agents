# %% [markdown]
# ## Installation
#
# We will need to install a number of libraries to start with.

# %%
import networkx as nx
# !pip install transformers
# !pip install sentencepiece

# %% [markdown]
# We use flan alpaca model for speed and local execution.

# %%
from transformers import pipeline

prompt = "Write an email about an alpaca that likes flan"
model = pipeline(model="declare-lab/flan-alpaca-xl", device=0)
model(prompt, max_length=128, do_sample=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# [{'generated_text': 'You can imagine the surprise of people when they get an email that their alpaca likes a certain type of flan. As some of you may know, an alpaca is a mammal that has evolved over the centuries to become a very specialized species of domestic animal. Alpacas are known for their ability to fly, and they are often seen as an attractive and intelligent animal. Not to mention their sweet taste buds! It is believed that alpacas love flan because they think it tastes delicious and they enjoy trying out different items. You can find their favorite type of fla'}]

# %%
from transformers import pipeline
import networkx as nx
prompt = '''### Instruction:
Who is the first person on the moon?

### Response:'''
def generate(prompt):
  output = model(prompt, do_sample=True, min_length=10, max_length=len(prompt)+128)
  out = output[0]['generated_text']
  if '### Response:' in out:
    out = out.split('### Response:')[1]
  if '### Instruction:' in out:
    out = out.split('### Instruction:')[0]
  return out

# %% [markdown]
# ## World Description
# We describe the world below. We will generate prompts based on this information. The simulation is that of the town of Phandalin, southwest of Neverwinter. This area is chosen because it is easily extendable with multiple regions for a "player" to be able to explore the world once the simulation is done.

# %%
world_graph = nx.Graph()

prompt_meta = '''### Instruction:
{}

### Response:'''

town_areas = ["Barthen's Provisions", "Lionshield Coster", "Stonehill Inn", "Phandalin Town Square"]
town_areas = {"Phandalin Town Square": 'Town square of the town of Phandalin.',
              'Stonehill Inn': "In the center of town stands a large, newly built roadhouse of fieldstone and rough-hewn timbers. The common room is filled with locals nursing mugs of ale or cider, all of them eyeing you with curiosity.",
              "Barthen's Provisions": "Barthen’s is the biggest trading post in Phandalin. Its shelves stock most ordinary goods and supplies, including backpacks, bedrolls, rope, and rations. The place is open from sunup to sundown.",
              "Edermath Orchard": "A tidy little cottage beside an apple orchard.",
              "Lionshield Coster": "Hanging above the front door of this modest trading post is a sign shaped like a wooden shield with a blue lion painted on it. This building is owned by the Lionshields, a merchant company based in the city of Yartar, over a hundred miles to the east. They ship finished goods to Phandalin and other small settlements throughout the region, but this outpost has been hard hit by banditry. The most recent Lionshield caravan due in Phandalin never arrived.",
              "Phandalin Miner's Exchange": "The Miner’s Exchange is a trading post where local miners have their valuable finds weighed, measured, and paid out. In the absence of any local lord or authority, the exchange also serves as an unofficial records office, registering claims to various streams and excavations around the area. There isn’t any real gold rush in Phandalin, but enough wealth is hidden in the nearby streams and valleys to support a good number of independent prospectors. The exchange is a great place to meet people who spend a lot of time out and about in the countryside surrounding Phandalin. The guildmaster is an ambitious and calculating human woman named Halia Thornton.",
              "Alderleaf Farm": "A farm owned by the helpful halfling farmer, Qelline Alderleaf.",
              "Shrine of Luck": "Phandalin's only temple is a small shrine made of stones taken from the nearby ruins. It is dedicated to Tymora, goddess of luck and good fortune.",
              "The Sleeping Giant": "This rundown tap house is a dirty, dangerous watering hole at the end of Phandalin’s main street. It is frequented by Redbrand thugs and operated by a surly female dwarf named Grista.",
              "Townmaster’s Hall": "The townmaster’s hall has sturdy stone walls, a pitched wooden roof, and a bell tower at the back. Posted on a board next to the front door is a notice written in Common. It reads: “REWARD — Orcs near Wyvern Tor! Those of a mind to face the orc menace should inquire within.” The notice bears the town’s seal and an indecipherable signature.",
              "Tresendar Manor": "A ruined manor. The Redbrands’ base in Phandalin is a dungeon complex under Tresendar Manor. Before the manor was ruined, its cellars served as safe storage for food and water in the event that the estate was attacked, while an adjoining crypt provided a resting place for the deceased members of the Tresendar family. The Redbrands have since expanded the cellars to suit their own purposes, adding slave pens, workshops, and barracks."
              }
town_people = {"Toblen Stonehill": "Toblen owns a trading post.", 
               "Daran Edermath": "Daran is a retired adventurer who lives in a tidy little cottage beside an apple orchard. A fit, silver-haired half-elf well over a hundred years old, Daran is a fighter who served as a marshal and herald for many years in the lands of the Dragon Coast, far to the southeast. Upon retiring, he returned to the Neverwinter region, his original home.",  
               "Linene Graywind": "Linene runs a trading post.",  
               "Halia Thornton": "Halia is an ambitious and calculating human woman. She is the guildmaster of Phandalin Miner’s Exchange, a trading post where local miners have their valuable finds weighed, measured, and paid out. In her attempts to establish the Miner's Exchange as the closest thing the town has to a governing authority, she acts as more than a simple merchant.",  
               "Qelline Alderleaf": "Qelline is a wise female halfling of forty-five, and is a pragmatic farmer who seems to know everything that goes on in town. She is a kind host, and is willing to let the characters stay in her hayloft if they don't want to stay at the Stonehill Inn.",  
               "Sister Garaele": "Sister Garaele is an elf cleric of Tymora and a Harper agent.", 
               "Harbin Wester": "Harbin is the townmaster of Phandalin. A pompous, old fool. Phandalin has no functioning government, but the townsfolk elect someone to serve as townmaster each year. The townmaster serves as a judge in minor disputes and keeps any records that need to be kept.",
               "Terrill Bloodscar": "Terrill is a human ruffian. He wears a grimy scarlet cloak. He is a member of the Redbrand ruffians. He doesn't like adventurers, and wants to rob and kill them.",
               "Conrad Scarface": "Conrad is a human ruffian. He wears a grimy scarlet cloak. He is a member of the Redbrand ruffians. He doesn't like adventurers, and wants to rob and kill them.",
               "Nellie Starsmith": "Nellie is a human ruffian. She wears a grimy scarlet cloak. She is a member of the Redbrand ruffians. She doesn't like adventurers, and wants to rob and kill them.",
               "Valerie Grinblade": "Valerie is a human ruffian. She wears a grimy scarlet cloak. She is a member of the Redbrand ruffians. She doesn't like adventurers, and wants to rob and kill them.",
               }
for town_area in town_areas.keys():
  world_graph.add_node(town_area)
  world_graph.add_edge(town_area, town_area)
for town_area in town_areas.keys():
  world_graph.add_edge(town_area, "Phandalin Town Square")
locations = {}
for i in town_people.keys():
  locations[i] = "Phandalin Town Square"


memories = {}
for i in town_people.keys():
  memories[i] = []
plans = {}
for i in town_people.keys():
  plans[i] = []

global_time = 8
def generate_description_of_area(x):
  text = "It is "+str(global_time)+":00. The location is "+x+"."
  people = []
  for i in locations.keys():
    if locations[i] == x:
      people.append(i)

# %%
compressed_memories_all = {}
for name in town_people.keys():
  compressed_memories_all[name] = []

# %%
for name in town_people.keys():
  prompt = "You are {}. {} You just woke up in the town of Phandalin and went out to the Town Square. The following people live in the town: {}. What is your goal for today? Be brief, and use at most 20 words and answer from your perspective.".format(name, town_people[name], ', '.join(list(town_people.keys())) )
  plans[name] = generate(prompt_meta.format(prompt))
  print(name, plans[name])
# Out:
# Toblen Stonehill Toplen's goal for today is to make some money for his trading post.
# Daran Edermath Today, my goal is to find a new recipe for apple trees.
# Linene Graywind Linene's goal for today is to sell some of the goods she has acquired for the trading post. She plans to find a buyer for one of the items she currently has.
# Halia Thornton Today I aim to build the Miner's Exchange into the dominant entity in the town and expand its reach.
# Qelline Alderleaf My goal for today is to chat with new people and take in the town scene!
# Sister Garaele To find out what the Harpers are up to.
# Harbin Wester Harbin Wester - judge disputes and keep records.
# Terrill Bloodscar To rob and kill adventurers.
# Conrad Scarface To rob the adventurers in the town.
# /opt/conda/envs/torchdata/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Nellie Starsmith To make money off of adventurers.
# Valerie Grinblade my goal for today is to rob adventurers in the town square and claim it for myself.

# %%
action_prompts = {}
for location in town_areas.keys():
  people = []
  for i in town_people.keys():
    if locations[i] == location:
      people.append(i)
  
  for name in people:
    prompt = "You are {}. {} You are planning to: {}. You are currently in {} with the following description: {}. It is currently {}:00. The following people are in this area: {}. You can interact with them.".format(name, town_people[name], plans[name], location, town_areas[location], str(global_time), ', '.join(people))
    people_description = []
    for i in people:
      people_description.append(i+': '+town_people[i])
    prompt += ' You know the following about people: ' + '. '.join(people_description)
    memory_text = '. '.join(memories[name][-10:])
    prompt += "What do you do in the next hour? Use at most 10 words to explain."
    action_prompts[name] = prompt

# %%
action_results = {}
for name in town_people.keys():
  action_results[name] = generate(prompt_meta.format(action_prompts[name]))
  # Now clean the action
  prompt = """
  Convert the following paragraph to first person past tense:
  "{}"
  """.format(action_results[name])
  action_results[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
  print(name, action_results[name])
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (846 > 512). Running this sequence through the model will result in indexing errors
# Toblen Stonehill I set up a table in the center of Phandalin Town Square and began trading.
# Daran Edermath I greet the people in Phandalin Town Square. Then, I chat with several others in order to find out more about how to make apple trees.
# Linene Graywind Invested in a suitable business - Linene likely focused on finding a buyer for the new trading post item.
# Halia Thornton I sought to build the Miners Exchange into a dominant entity in the town, enlist the help of those in the square and have a successful day.
# Qelline Alderleaf Quilline chatting with new people and taking in the town scene.
# Sister Garaele I found out what Harpers are doing in town.
# Harbin Wester I had first light discussions with people in Town Square. Judged any disputes that arise. Gathered records.
# Terrill Bloodscar Terrill joined Nellie and Conrad for a robbery and murder mission.
# Conrad Scarface Conrad planned out a plan to rob the adventurous locals in the next hour.
# Nellie Starsmith I planned to rob and kill adventurers.
# Valerie Grinblade I struck while the iron was hot. I didnt have long to make an impact.

# %% [markdown]
# Collect the memories people observe.

# %%
action_prompts = {}
for location in town_areas.keys():
  people = []
  for i in town_people.keys():
    if locations[i] == location:
      people.append(i)
  
  for name in people:
    for name_two in people:
      memories[name].append('[Time: {}. Person: {}. Memory: {}]\n'.format(str(global_time), name_two, action_results[name_two]))

# %% [markdown]
# # Rank Memories

# %%
import re
def get_rating(x):
  nums = [int(i) for i in re.findall(r'\d+', x)]
  if len(nums)>0:
    return min(nums)
  else:
    return None

# %%
memory_ratings = {}
for name in town_people.keys():
  memory_ratings[name] = []
  for i, memory in enumerate(memories[name]):
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Give a rating, between 1 and 5, to how much you care about this.".format(name, plans[name], locations[name], str(global_time), memory)
    res = generate(prompt_meta.format(prompt))
    rating = get_rating(res)
    max_attempts = 2
    current_attempt = 0
    while rating is None and current_attempt<max_attempts:
      rating = get_rating(res)
      current_attempt += 1
    if rating is None:
      rating = 0
    memory_ratings[name].append((res, rating))
  print(memory_ratings[name])
# Out:
# [('5: I care very much about this outcome and will do my best to reach my goal.', 5), ('4 out of 5 stars. This is particularly helpful as I am going to Phandalin Town Square to make money for my trading post.', 4), ('I rate this 3 out of 5. Linene is an excellent role model for how an individual should conduct their business, with dedication, respect and a strong moral compass.', 3), ('5 stars. This activity is very important for accomplishing your goals and contributing to the success of the Miners Exchange.', 5), ('3/10. You care about Quilline and the town scene, but it is not enough to make a significant difference to your goal of making money for your trading post.', 3), ('3 (Rating of Relevance): I care about this but not enough to bother taking the time to care.', 3), ('2 because I am currently working towards making money for my trading post.', 2), ('3 (Not very much) because it is not important to me.', 3), ("3/5 I care about this since it could possibly impact on Toplen's plans for the day.", 3), ('4 (It is important to keep an eye out for Nellie and her memory).', 4), ('3 (not important) This task was not completed as it was not part of Toblen’s plan for today.', 3)]
# [('3/5. Toblen Stonehill was very kind and cooperative and it was nice to see him in such a positive light to start the day. His presence was something to behold and we both felt lucky to have been blessed with his presence in Phandalin Town Square.', 3), ('5 (Excellent) I care enough to observe this.', 5), ('3/5. Linene likely has a lot of work ahead of her, so Daran should give her a special rate to ensure she gets the best support.', 3), ('4/5. I care about what Halia is doing in the square now.', 4), ('3 because I am working on my goal and it may take some time for me to finish my observation.', 3), ('3/5. I find the conversation to be relevant to my goal of finding a new recipe for apple trees, and I am interested to see how Sister Garaele relates to the situation.', 3), ("4/5. This is important for Daran's plan of finding a new recipe.", 4), ("2 (Don't care) because I am focused on finding a new recipe for apple trees.", 2), ('3/5 because I am mainly looking for a new recipe.', 3), ("0.4. No, don't worry. I'm still working on my apple tree recipe.", 0), ('3/5 I care about the situation, but I am not currently in a place to make a move. I should focus on my own objectives first.', 3)]
# [('3 (not important): This information does not concern Linene Graywind and is insignificant.', 3), ('3/5. I admire Daran Edermath for taking initiative in meeting people, exploring the surrounding area, and engaging in meaningful conversations in order to learn more about making apple trees.', 3), ('5 stars. Linene is highly motivated and driven towards her goal of finding a buyer for one of her new trading post items.', 5), ("4/5. I value Halia's presence in the square for her insight into navigating the market and her experience with negotiations.", 4), ('2 because Linene is currently focusing on selling some of the goods she has acquired for the trading post, and observing Quilline Alderleaf as she takes in the town scene is not of importance, and the time she had with her is more important.', 2), ('2/5. I am very interested to know what Harpers are up to in town.', 2), ('3 This memory is not of importance to Linene.', 3), ('3/5. This information is of significance to Linene, as it shows her that the villain Terrill Bloodscar is present in the town. This increases her chances of achieving her goal of selling goods.', 3), ('3/5. She cares very little about it as she is much more concerned with selling her goods.', 3), ('2 (Not very caring) as I have other priorities tonight.', 2), ('2 (Not important) The event that occurred at 8:01 has a rating of zero. Why is it important? Because it means Valerie Grinblade could have gotten the job earlier if she had taken the initiative. In addition, it means that Linene can have a quick update on her progress in selling the goods and meeting her goal. So, it is a positive outcome. The rating for this event is zero.', 1)]
# [('4 out of 5; I care about this very much.', 4), ('3/5 stars. I care enough about this to make a small effort in this area.', 3), ("5 I care about this. Linene is the key figure in Phandalin Town Square and her role in the success of the Miner's Exchange is crucial. Additionally, the development of the trading post should be an important component of his plans for today.", 5), ('5 ', 5), ("5 I care a lot about this as it helps to build the Miner's Exchange become the dominant entity in the town.", 5), ("4 (Careful)! Sister Garaele's knowledge of Harpers' activities in town could be an important source of insight into how to better shape what your store is doing. She would be an invaluable asset and help you find creative solutions to your problems.", 4), ('3/5. This is important to me since I need to make sure my plans take precedence over my emotions. The only way I can find solutions on how to make this work is by taking an active role in the situation and using my knowledge and skills to make it better.', 3), ("2 because I am doing nothing to help Terrill in this situation and I can't help but think about my plans for the town and my goals.", 2), ("2 out of 5 stars. I could care less about Conrad's dangerous plan, but it's important for the progress of the Miner's Exchange to know where he is and what he is up to. Likewise, observing that Halia is in Phandalin Town Square suggests an interest in their interests too.", 2), ('2 because you do not care enough to do anything about it.', 2), ("4/5. I care about this because it can be a good indicator of how I'm performing on the goals I set for myself.", 4)]
# [('3; I care about this slightly, but I would also be interested in chatting with new people and enjoying the town scene more.', 3), ('5 (Very important) I care very much about this. I am eager to learn more about how to make apple trees.', 5), ('3/5 stars. Linene is dedicated to her task, and there is already much success in place. You could potentially invest in something similar and benefit from the knowledge she has.', 3), ("3/5. You have taken interest in what Halia Thornton did for the Miners Exchange. It highlights how important the town's civic activities are.", 3), ('5 (important): It is important that Qelline Alderleaf focuses on getting to know new people and taking in the town scene.', 5), ('5 (Very important). This information is important to me, and I am currently doing my best to find out what is going on in Phandalin Town Square.', 5), ('4 Please rate how much you care about this.', 4), ("I care about this, but not enough to take notice of or make a decision. The time zone difference would prevent me from seeing the plot, so I guess it's pointless. I like to focus on enjoying the moments while people watching. Have a great day!", 0), ('4 for the amount of attention it receives.', 4), ("1 because you don't care about this.", 1), ('5 (Not Very) to see this.', 5)]
# [("Rating: 3 (Not Very Much) The scene in Phandalin Town Square at 8:00 is probably of little sentimental value to Sister Garaele. She can't help feeling a sense of disappointment and curiosity, since that is when she'll find out what the Harpers are up to.", 0), ('3 (Unimportant)...nothing else is important.', 3), ('3/5. I care about finding out what the Harpers are up to, and I think Linene Graywind is doing a good job capitalizing on the economic opportunities and setting up a successful business in Phandalin.', 3), ('3 out of 5. I am sure that Halia Thornton is thinking carefully about your desire to build the Miners Exchange into a dominant entity in the town, and appreciates taking the time to talk to you. I am looking forward to finding out more about the Harper family and their plans.', 3), ("5 (very important) I have been observing Quilline Alderleaf in Phandalin Town Square for a few minutes now and I think I can help by finding out what the Harpers are up to. I'm on my way to the Harpers' secret location and I think this observation could be useful.", 5), ('4 [Output][Interest]', 4), ('3 (Not important) This task requires minimal effort.', 3), ('3/5. Sister Garaele cares deeply about what happened to Terrill and the Harpers. She must find out who is behind their dangerous plan and what secrets the Harpers are keeping.', 3), ("3/5. I care enough to investigate to find out what Conrad Scarface's plan was.", 3), ('3/5 star. I care deeply about the Harpers and their plans to rob and kill adventurers. I have therefore contacted Sister Garaele and am collecting and analyzing information on them.', 3), ('3/5 (Rating of importance to Sister Garaele)', 3)]
# [("5 I care greatly about this activity. It is important to me that I continue to improve the quality of citizens' lives. So, I would rate this activity a 3 out of 5.", 3), ("3/5. I care about Daran's activity very much, and I hope to further engage with him to learn more about creating apple trees.", 3), ('2/5. This experience will help me to better understand the needs of my citizens and to ensure my courtship is fair and effective.', 2), ("3/5. I am interested in this person's memory and am determined to ensure their legacy continues to be remembered.", 3), ('3/5. I care about this as I am a judge to ensure justice and recordkeeping.', 3), ("4 (Don't really care) because it is not important for Harbin Wester to be concerned.", 4), ('5 (important): I care deeply about this mission and am committed to completing it.', 5), ('3/5. Harbin Wester - Judge disputes and keep records.', 3), ('3/5. I am observing the situation carefully and am concerned that Conrad Scarface may attempt to rob the civilians in the next hour. I want to be sure that laws are enforced and take all necessary actions to protect the innocent citizens. I hope an outcome can be reached.', 3), ('5 (very important): I am concerned about the safety of everyone in the square and I am committed to catching any criminal(s) responsible for such activity. I have ordered an investigation to be completed and to ensure that anyone responsible is brought to justice.', 5), ("2/5. I find it interesting for the moment and would like to hear more about the person's story.", 2)]
# [('3 (Little) care. I am not presently in need of this. Observation: 8:08 PM.', 3), ('2 (Not Very) because it is not important to me and I am more interested in gaining experience and killing adventurers.', 2), ('3/5, because stealing for profit is the only reward I can offer for my crimes.', 3), ('3/5. You are not interested in dealing with the locals, and would rather concentrate on your planned robbery.', 3), ('3/5 Considering my plan to rob and kill adventurers, I care very little about this.', 3), ("3/5. I am not particularly interested in the person's memory, but I am intrigued by what Harper is doing.", 3), ('3/10. I care about this a bit, but nothing that I need to worry about in the meantime.', 3), ('3 out of 5 (Because I am just playing the game).', 3), ('5 (very important)! This information is essential to my plan for the next hour. It allows me to quickly gather information and execute my plans.', 5), ('3/5. I care little about this.', 3), ('2/10. I care little about this person, as my main goal is to rob and kill.', 2)]
# [('3/10. I value the information provided but would like to focus on my goal of robbing the adventurers.', 3), ('Unimportant to me. My priority is to rob the adventurers in my current location.', 0), ("0.75. This info doesn't matter to me since my main goal is to rob the adventurers. I am just doing my job as a thief and it's not relevant to my mission.", 0), ("0.5. I don't care about this situation.", 0), ('3/5. Taking in the town scene while robbing the adventurers is something I am absolutely not interested in. It would be better for me to focus on completing my goal and dealing out punishment to the perpetrator.', 3), ('3/5. This information is likely of great significance to Conrad Scarface so he will take the time to investigate it and assess the situation. Is it likely that the Harpers will still be present when the robbery takes place?', 3), ('3/5. This is interesting and beneficial to my plan.', 3), ('5 (important) ', 5), ("3/5. Conrad's plan to rob the adventurers in the next hour is of critical importance for his success, and this level of concern should be fully expressed in his action plan.", 3), ('4/5. Now I have more reason to pause my plans.', 4), ('2/5. You care deeply about Valerie, and could easily be lured into getting into a trap.', 2)]
# [("4 (It's a great opportunity to make money)", 4), ('3/5. Because it is important for Nellie Starsmith’s success, she cares enough to get to work on the task at hand soon.', 3), ('I care about this because it will help me to make money from the adventurers.', 0), ('2/5. Nellie needs help to build her empire and get a successful day.', 2), ('2 because Nellie is more focused on making money than being a social butterfly.', 2), ("3 out of 5 - I don't care enough to pay attention to this, it isn't relevant for my plans.", 3), ("3 (Minor) Rating. This indicates that I have taken note of Harbin Wester's memory as it is a major part of making money off of adventurers. I am going to try to take advantage of the situation.", 3), ('4 because I care about making money off of adventurers.', 4), ('Rating: 3 out of 5 (Only really important for now)', 3), ('2/5. This task requires a large amount of creativity and attention to detail.', 2), ('3/5 stars. I care very much about this information and I am ready to make the most money I can off of it.', 3)]
# [("3 out of 5 stars. I care about this as part of my plan, but I don't need to worry about it at this time.", 3), ('3/5. You care more about your goal than being a good citizen.', 3), ('3 or 4 since Valerie Grinblade cares about making money from her robbery plans.', 3), ('2 ### Rating: 2.3333333333', 2), ('3/5. While observing Quilline Alderleaf in the town square, I felt a deep desire to pursue my mission of robbery. However, when I saw the other people around me chatting with people and taking in the town, I was caught off guard and became awe.', 3), ('3 (Not a big deal) Meanwhile, I make preparations for my target.', 3), ('5 Because I can see that the people in Phandalin Town Square are being taken care of by a hero who has taken the opportunity to observe. This makes me want to participate in their activity.', 5), ('2/5. I care about this information heavily, and I am determined to use it in my planning for the day.', 2), ("2 out of 5 stars. The timing of this information is relevant to my plan, and provides an opportunity for me to learn more about Conrad's plans and exploit the situation for my own advantage. Thus, I am excited to be able to utilize this information to my advantage.", 2), ('4 because I care a lot about this. I must be thinking of a way to accomplish my goal.', 4), ('4/5. This reminder helps me stay focused on my goal.', 4)]

# %% [markdown]
# # Compress Memories

# %%
MEMORY_LIMIT = 10
compressed_memories = {}
for name in town_people.keys():
  memories_sorted = sorted(
        memory_ratings[name], 
        key=lambda x: x[1]
    )[::-1]
  relevant_memories = memories_sorted[:MEMORY_LIMIT]
  # print(name, relevant_memories)
  memory_string_to_compress = '.'.join([a[0] for a in relevant_memories])
  prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Summarize these memories in one sentence.".format(name, plans[name], locations[name], str(global_time), memory_string_to_compress)
  res = generate(prompt_meta.format(prompt))
  compressed_memories[name] = '[Recollection at Time {}:00: {}]'.format(str(global_time), res)
  compressed_memories_all[name].append(compressed_memories[name])

# %%
place_ratings = {}

for name in town_people.keys():
  place_ratings[name] = []
  for area in town_areas.keys():
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You have the following memories: {}. Give a rating, between 1 and 5, to how likely you are likely to be at {} the next hour.".format(name, plans[name], locations[name], str(global_time), compressed_memories[name], area)
    res = generate(prompt_meta.format(prompt))
    rating = get_rating(res)
    max_attempts = 2
    current_attempt = 0
    while rating is None and current_attempt<max_attempts:
      rating = get_rating(res)
      current_attempt += 1
    if rating is None:
      rating = 0
    place_ratings[name].append((area, rating, res))
  place_ratings_sorted = sorted(
      place_ratings[name], 
      key=lambda x: x[1]
  )[::-1]
  if place_ratings_sorted[0][0] != locations[name]:
    new_recollection = '[Recollection at Time {}:00: {}]'.format(str(global_time), 'I then moved to {}.'.format(place_ratings_sorted[0][0]))
    compressed_memories_all[name].append(new_recollection)
  locations[name] = place_ratings_sorted[0][0]

# %% [markdown]
# # Put it all together

# %%
for repeats in range(20):
  global_time += 1
  action_prompts = {}
  for location in town_areas.keys():
    people = []
    for i in town_people.keys():
      if locations[i] == location:
        people.append(i)
    
    for name in people:
      prompt = "You are {}. Your plans are: {}. You are currently in {} with the following description: {}. Your memories are: {}. It is currently {}:00. The following people are in this area: {}. You can interact with them.".format(name, plans[name], location, town_areas[location], '\n'.join(compressed_memories_all[name][-5:]), str(global_time), ', '.join(people))
      people_description = []
      for i in people:
        people_description.append(i+': '+town_people[i])
      prompt += ' You know the following about people: ' + '. '.join(people_description)
      memory_text = '. '.join(memories[name][-10:])
      prompt += "What do you do in the next hour? Use at most 10 words to explain."
      action_prompts[name] = prompt
  action_results = {}
  for name in town_people.keys():
    action_results[name] = generate(prompt_meta.format(action_prompts[name]))
    # Now clean the action
    prompt = """
    Convert the following paragraph to first person past tense:
    "{}"
    """.format(action_results[name])
    action_results[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
    print(name, locations[name], global_time, action_results[name])
  action_emojis = {}
  for name in town_people.keys():
    prompt = """
    Convert the following paragraph to a tuple (Action, Object):
    "{}"
    """.format(action_results[name])
    action_emojis[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
    print('    - Emoji Representation:', name, locations[name], global_time, action_emojis[name])
  action_prompts = {}
  for location in town_areas.keys():
    people = []
    for i in town_people.keys():
      if locations[i] == location:
        people.append(i)
    
    for name in people:
      for name_two in people:
        memories[name].append('[Time: {}. Person: {}. Memory: {}]\n'.format(str(global_time), name_two, action_results[name_two]))

  memory_ratings = {}
  for name in town_people.keys():
    memory_ratings[name] = []
    for i, memory in enumerate(memories[name]):
      prompt = "You are {}. Your plans are: {}. Your memories are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Give a rating, between 1 and 5, to how much you care about this.".format(name, plans[name], '\n'.join(compressed_memories_all[name][-5:]), locations[name], str(global_time), memory)
      res = generate(prompt_meta.format(prompt))
      rating = get_rating(res)
      max_attempts = 2
      current_attempt = 0
      while rating is None and current_attempt<max_attempts:
        rating = get_rating(res)
        current_attempt += 1
      if rating is None:
        rating = 0
      memory_ratings[name].append((res, rating))

  compressed_memories = {}
  for name in town_people.keys():
    memories_sorted = sorted(
          memory_ratings[name], 
          key=lambda x: x[1]
      )[::-1]
    relevant_memories = memories_sorted[:MEMORY_LIMIT]
    memory_string_to_compress = '.'.join([a[0] for a in relevant_memories])
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Summarize these memories in one sentence.".format(name, plans[name], locations[name], str(global_time), memory_string_to_compress)
    res = generate(prompt_meta.format(prompt))
    compressed_memories[name] = '[Recollection at Time {}:00: {}]'.format(str(global_time), res)
    compressed_memories_all[name].append(compressed_memories[name])

  place_ratings = {}

  for name in town_people.keys():
    place_ratings[name] = []
    for area in town_areas.keys():
      prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You have the following memories: {}. Give a rating, between 1 and 5, to how likely you are likely to be at {} the next hour.".format(name, plans[name], locations[name], str(global_time), compressed_memories[name], area)
      res = generate(prompt_meta.format(prompt))
      rating = get_rating(res)
      max_attempts = 2
      current_attempt = 0
      while rating is None and current_attempt<max_attempts:
        rating = get_rating(res)
        current_attempt += 1
      if rating is None:
        rating = 0
      place_ratings[name].append((area, rating, res))
    place_ratings_sorted = sorted(
        place_ratings[name], 
        key=lambda x: x[1] )[::-1]
    if place_ratings_sorted[0][0] != locations[name]:
      new_recollection = '[Recollection at Time {}:00: {}]'.format(str(global_time), 'I then moved to {}.'.format(place_ratings_sorted[0][0]))
      compressed_memories_all[name].append(new_recollection)
    locations[name] = place_ratings_sorted[0][0]
# Out:
# Toblen Stonehill Phandalin Miner's Exchange 9 I went inside and looked for potential customers.
# Daran Edermath Stonehill Inn 9 I browsed the inventory for ideas and took notes on recipes to try out.
# Linene Graywind Phandalin Miner's Exchange 9 Linene looked for a buyer for one of her items and talked with Toblen Stonehill to see if they could help.
# Halia Thornton The Sleeping Giant 9 My intention was to make the Miners Exchange the towns main source of wealth and services. I have been working tirelessly to promote the new building, in order to ensure that its construction, expansion, and management was in line with my plans.
# Qelline Alderleaf Phandalin Town Square 9 Qelline chatted with Qelline, Valerie Grinblade on their plan for the next hour.
# Sister Garaele Tresendar Manor 9 - Engaged Terrill in combat.
# Harbin Wester Townmaster’s Hall 9 I judged disputes in minor disputes and kept records.
# Terrill Bloodscar Tresendar Manor 9 Terrill Bloodscar: [Its time to act]
# Conrad Scarface Edermath Orchard 9 Conrad Scarface targeted the adventurers in the nearby village of Phandalin Town Square.
# Nellie Starsmith The Sleeping Giant 9 I collected the memories of other adventurers, and completed my plans - I earned my money - with the help of Harbin Wester.
# Valerie Grinblade Phandalin Town Square 9 Valerie Grinblade: I decide to wait for the right time and await any suspicious behaviour in the town square. I leave when I see Qelline Alderleaf appear. Then I can plan my revenge.
#     - Emoji Representation: Toblen Stonehill Phandalin Miner's Exchange 9 I, went, inside, looked. (Action: went, Object: possible customers, Object: customers)
#     - Emoji Representation: Daran Edermath Stonehill Inn 9 Action: browsed * Object: inventory Result: found some recipes to try out
#     - Emoji Representation: Linene Graywind Phandalin Miner's Exchange 9 Linene -> looked, Toblen -> Stonehill
#     - Emoji Representation: Halia Thornton The Sleeping Giant 9 Intention: make the Miners Exchange the towns main source of wealth and services Action: promoted the new building Object: new building
#     - Emoji Representation: Qelline Alderleaf Phandalin Town Square 9 Qelline | Chatted |Qelline, Valerie Grinblade | On their plan for the next hour.
#     - Emoji Representation: Sister Garaele Tresendar Manor 9 Action: Engaged Terrill in combat.
#     - Emoji Representation: Harbin Wester Townmaster’s Hall 9 I judged disputes, kept records. (Action => Object)
#     - Emoji Representation: Terrill Bloodscar Tresendar Manor 9 Action: Its time to act. Object: Terrill Bloodscar.
#     - Emoji Representation: Conrad Scarface Edermath Orchard 9 Conrad Scarface | Targeted | Adventurers | Phandalin Town Square
#     - Emoji Representation: Nellie Starsmith The Sleeping Giant 9 Action: collected, Object: memories, Object: money Helper: Harbin Wester.
#     - Emoji Representation: Valerie Grinblade Phandalin Town Square 9 Valerie Grinblade, Observe suspicious behaviour in the town square. Valerie Grinblade, Leave when she sees Qelline Alderleaf appear. Valerie Grinblade, Plan revenge.
# Toblen Stonehill Alderleaf Farm 10 Toblen went to the Halfling Farm in the next hour to collect fresh fruit for his trading post. He then returned to his trading post to make money from trading for other goods.
# Daran Edermath Lionshield Coster 10 I headed to the nearby orchard to investigate.
# Linene Graywind Shrine of Luck 10 Linnet talked to Harbin and Nellie to build my courage and figure out a way to find a buyer for an item I have acquired for the trading post.
# Halia Thornton Phandalin Miner's Exchange 10 I focused on creating a better foundation for the business, and built a network of contacts. I also put effort into improving the exchanges efficiency and effectiveness.
# Qelline Alderleaf Stonehill Inn 10 I continued chatting with locals and exploring the town.
# Sister Garaele Tresendar Manor 10 I explored the cellars. I encountered Conrad Scarface. I discovered Harpers secret location.
# Harbin Wester Shrine of Luck 10 I continued to maintain the peace and judge disputes.
# Terrill Bloodscar Townmaster’s Hall 10 I investigated the board of orcs.
# Conrad Scarface Tresendar Manor 10 I resolved to rob the adventurers in Tresendar Manor.
# Nellie Starsmith Shrine of Luck 10 Nell must have gone to the shrine of luck, both to interact with Harbin Wester and Linene Graywind and to plan her plan to rob and Kill the adventurers she encountered.
# Valerie Grinblade Phandalin Miner's Exchange 10 I moved to the town square and searched for adventurers.
#     - Emoji Representation: Toblen Stonehill Alderleaf Farm 10 [Action, Object]  [[Toblen, Halfling Farm, Fresh fruit], [Toblen, trader, goods, [trader, money, [trader, tokens]]
#     - Emoji Representation: Daran Edermath Lionshield Coster 10 A) Inquire B) Head to nearby orchard
#     - Emoji Representation: Linene Graywind Shrine of Luck 10 Linnet: talked Harbin: discussed Nellie: found
#     - Emoji Representation: Halia Thornton Phandalin Miner's Exchange 10 Action: Created a better foundation, built a network, improved the exchanges efficiency, effectiveness.
#     - Emoji Representation: Qelline Alderleaf Stonehill Inn 10 Action: Chatting, Object: Locals, Exploring.
#     - Emoji Representation: Sister Garaele Tresendar Manor 10 I explored, encountered, discovered span style=font-size:20px;>The Cellars/span>[a href=https://en.wikipedia.org/wiki/Corporate_Intelligence>Conrad Scarfaces Office/a>.
#     - Emoji Representation: Harbin Wester Shrine of Luck 10 Action: continued, Object: maintain, judge
#     - Emoji Representation: Terrill Bloodscar Townmaster’s Hall 10 Action: Investigated Object: Board of Orcs.
#     - Emoji Representation: Conrad Scarface Tresendar Manor 10 I -> resolved; I -> robbed; I -> Tresendar Manor;
#     - Emoji Representation: Nellie Starsmith Shrine of Luck 10 Nell, Object: went to the shrine of luck, both for interaction with Harbin Wester and Linene Graywind and for planning her plan to rob and kill the adventurers she encountered, both for fun.
#     - Emoji Representation: Valerie Grinblade Phandalin Miner's Exchange 10 Action: mov[ing], object: adventurers.
# Toblen Stonehill Shrine of Luck 11 He set out to explore Phandalin Miners Exchange, Harbin Westers shop and dungeon, and Terrill Bloodscars coven.
# Daran Edermath Townmaster’s Hall 11 Daran made conversation with Qelline and Sister Garaele.
# Linene Graywind Tresendar Manor 11 I plan to explore Tresendar Manors cellars.
# Halia Thornton Alderleaf Farm 11 Halia Thornton focused on increasing the Miners Exchanges influence and impact in the town. She conducted interviews with various organizations to spread awareness of the Miners Exchange. She sought out new partnerships to help expand the miners reach. Additionally, she provided local resources to increase the strength of the towns economy.
# Qelline Alderleaf Townmaster’s Hall 11 Qelline sat down with Daran Edermath and Sister Garaele and discussed plans for today and setting up a meeting with Nellie Starsmith.
# Sister Garaele Townmaster’s Hall 11 I investigated and spoke to the two antagonists, Nellie and Valerie. I observed them. I talked to Sister Garaele, who confirmed that there was something suspicious going on. I discussed with Sister Garaele and Professor Helen. Finally, I make my own conclusions and decide to leave.
# Harbin Wester Shrine of Luck 11 I judged disputes related to luck. Additionally, I performed recordkeeping tasks such as keeping legal documents, preparing for major events, and taking attendance at important events. I visited the trading post of Toblen Stonehill and interacted with Terrill Bloodscar.
# Terrill Bloodscar Shrine of Luck 11 I disrupted the adventures of Tom and others on Phandalin. When I entered the Shrine of Luck, an area of crumbling temples and ruins, filled with ghouls and shamans, I called to Toblen Stonehill, Harbin Wester and Terrill Bloodscar to enlist my help in completing my plot. I must locate and locate enough brave adventurers to rob for my own gain.
# Conrad Scarface The Sleeping Giant 11 Conrad robbed the adventurers in The Sleeping Giant.
# Nellie Starsmith Townmaster’s Hall 11 I hunted down the orcs and stole their gold.
# Valerie Grinblade Townmaster’s Hall 11 I prepared for my robbery by devising a scheme to outwit the guards at the town gate.
#     - Emoji Representation: Toblen Stonehill Shrine of Luck 11 Exploration Action, Objects:  Phandalin Miners Exchange, Harbin Wester Shop, Castle Hathor-  Harbin Wester Dungeon, Terrill Bloodscars coven
#     - Emoji Representation: Daran Edermath Townmaster’s Hall 11 Action: made Object: Qelline + Sister Garaele
#     - Emoji Representation: Linene Graywind Tresendar Manor 11 Action: plan Object: Tresendar Manors Cellars
#     - Emoji Representation: Halia Thornton Alderleaf Farm 11 [increase, impact, conducted,interviews,,sought,partnerships,.local,,resources,,improved,,increased,,decreased,]
#     - Emoji Representation: Qelline Alderleaf Townmaster’s Hall 11 Qelline sat down, Daran Edermath, Sister Garaele, discussions, setting up a meeting, Nellie Starsmith.
#     - Emoji Representation: Sister Garaele Townmaster’s Hall 11 Action: Investigated, spoke to Nellie, Valerie, observed; Action: Talked to Sister Garaele, confirmed there was something suspicious, discussed with Sister Garaele, Professor Helen; Action: Make Conclusion, decide to leave.
#     - Emoji Representation: Harbin Wester Shrine of Luck 11 Action: judged Object: luck Object: recordkeeping Object: keeping legal documents, preparing for major events, taking attendance Object: visiting Toblen Stonehill Object: trading post Object: Terrill Bloodscar
#     - Emoji Representation: Terrill Bloodscar Shrine of Luck 11 action: I disrupted the adventures of Tom and others on Phandalin, object: Shrine of Luck, an area of crumbling temples and ruins, filled with ghouls and shamans, action: Called Toblen Stonehill, Harbin Wester, Terrill Bloodscar, object: brave adventurers, action: rob for my own gain.
#     - Emoji Representation: Conrad Scarface The Sleeping Giant 11 Conrad: Robbed Adventurers  The Sleeping Giant.
#     - Emoji Representation: Nellie Starsmith Townmaster’s Hall 11 Action: hunted, Object: gold.
#     - Emoji Representation: Valerie Grinblade Townmaster’s Hall 11 Action: Prepare Object: Robbery
# Toblen Stonehill The Sleeping Giant 12 I confronted the Redbrand thugs in the Sleeping Giant to make more money for my trading post.
# Daran Edermath Phandalin Miner's Exchange 12 I entered Phandalin Miners Exchange shortly, talked to Daran and Nellie, and gained a new recipe for apple trees.
# Linene Graywind The Sleeping Giant 12 I looked for a buyer for one of my items in The Sleeping Giant. I try to make the most of my day by connecting with the locals and giving back to the community. I plan on gathering enough support to buy a few more items, then selling them in my trading post.
# Halia Thornton Lionshield Coster 12 I stayed in Lionshield Coster, engaged in a negotiation with Conrad Scarface to resolve the situation between my mining team and the ruffians.
# Qelline Alderleaf Edermath Orchard 12 Celelenne visited some of the other businesses in the area to get an overview of the towns operations. She also chatted with Nellie and Daran about their recent adventures.
# Sister Garaele Shrine of Luck 12 Sister Garaele attempted to uncover the Harper familys secret plan.
# Harbin Wester The Sleeping Giant 12 I resolved disputes, kept records, and tried to uphold justice.
# Terrill Bloodscar The Sleeping Giant 12 Terrill Bloodscar robbed, killed, and collected rewards.
# Conrad Scarface Lionshield Coster 12 I stole from the merchants and then joined with Conrad in the town square.
# Nellie Starsmith Phandalin Miner's Exchange 12 Nell murders adventurers at the Miners Exchange.
# Valerie Grinblade The Sleeping Giant 12 I waited and saw what happened. What happened was that my mom said “I need to take this job” and I said “Yeah, that’s great!”
#     - Emoji Representation: Toblen Stonehill The Sleeping Giant 12 Action: Confront Redbrand thugs, Object: More money for trading post.
#     - Emoji Representation: Daran Edermath Phandalin Miner's Exchange 12 Action: entered Phandalin Miners Exchange, talked to Daran and Nellie, obtained a new recipe for apple trees.
#     - Emoji Representation: Linene Graywind The Sleeping Giant 12 [looked for a buyer, buying a few more items, selling them in my trading post]
#     - Emoji Representation: Halia Thornton Lionshield Coster 12 I stayed in Lionshield Coster, Entered a negotiation with Conrad Scarface Object Resolved the situation between my mining team and the ruffians.
#     - Emoji Representation: Qelline Alderleaf Edermath Orchard 12 Celelenne Occurred to some businesses, area; [Action], to get an overview, town; [Object], with Nellie, Daran, about their recent adventures.
#     - Emoji Representation: Sister Garaele Shrine of Luck 12 Action, Object: Attempted to uncover the Harper familys secret plan.
#     - Emoji Representation: Harbin Wester The Sleeping Giant 12 Resolved, kept records, tried to uphold justice.
#     - Emoji Representation: Terrill Bloodscar The Sleeping Giant 12 Terrill Bloodscar - Robbed + Kill + Collect Rewards
#     - Emoji Representation: Conrad Scarface Lionshield Coster 12 Stole, Joined (with Conrad);
#     - Emoji Representation: Nellie Starsmith Phandalin Miner's Exchange 12 Nell, Adventurers, Miners Exchange.
#     - Emoji Representation: Valerie Grinblade The Sleeping Giant 12 Action | Object: my mom said I need to take this job | My response: Yeah, thats great!
# Toblen Stonehill Townmaster’s Hall 13 I searched for the orcs. I will search for the orcs and find out where they are headed.
# Daran Edermath Alderleaf Farm 13 I await my answer from Daran. I found out that Sister Garaele is talking about the Harpers and what I can do to help, such as robbing a thief or a criminal known as Valerie Grinblade.
# Linene Graywind Barthen's Provisions 13 Linene advertised her goods and sought buyers. She prepared lists of potential buyers and made calls on interested parties.
# Halia Thornton Phandalin Miner's Exchange 13 I made an offer to the town for the construction of a new outpost to further expand the reach of the Miners Exchange.
# Qelline Alderleaf Phandalin Miner's Exchange 13 I took advantage of the space to chat, meet new people, observe the towns life.
# Sister Garaele Alderleaf Farm 13 I searched the surrounding areas for further signs of the Harpers activity.
# Harbin Wester Phandalin Miner's Exchange 13 Judged conflicts, kept records. Introduced Halia Thornton and Qelline Alderleaf, and arranged for her to stay behind in her hayloft for the night. - Set up the Miner’s Exchange and manage its affairs.
# Terrill Bloodscar Tresendar Manor 13 At 13:00 I had moved to Tresendar Manor to start my robbery and murder plans.
# Conrad Scarface The Sleeping Giant 13 Conrad prepared to rob the adventurers in the next hour.
# Nellie Starsmith Edermath Orchard 13 I was out and about. I had been patrolling the area looking for adventurers. During the day, I had been speaking to people in my cottage and the surrounding area. I had observed and learned from everyone in order to better my skills and operations.
# Valerie Grinblade Alderleaf Farm 13 In the next hour, I gathered the robbers and chased them across town. I aimed to claim the town squares rumored treasure and make it back to my farms owners.
#     - Emoji Representation: Toblen Stonehill Townmaster’s Hall 13 Action: search Object: orcs Result: knew where they were headed.
#     - Emoji Representation: Daran Edermath Alderleaf Farm 13 action, object: answer daran find out, object: Sister Garaele discuss about Harpers, object: Valerie Grinblade
#     - Emoji Representation: Linene Graywind Barthen's Provisions 13 Linene -> Advertised, -> Searched, -> Preparing, -> Making Calls -> Interested Parties
#     - Emoji Representation: Halia Thornton Phandalin Miner's Exchange 13 Action: offered Object: new outpost
#     - Emoji Representation: Qelline Alderleaf Phandalin Miner's Exchange 13 I took advantage of the space adverb to chat, meet new people, observe the towns life
#     - Emoji Representation: Sister Garaele Alderleaf Farm 13 Action: searched Object: Harpers activity
#     - Emoji Representation: Harbin Wester Phandalin Miner's Exchange 13 Action, Object: judged conflicts, kept records, introduced, arranged, - set up, manage.
#     - Emoji Representation: Terrill Bloodscar Tresendar Manor 13 Action, Object: robbery, murder.
#     - Emoji Representation: Conrad Scarface The Sleeping Giant 13 Conrad: Prepared, Adventurers: Robbed in the next hour.
#     - Emoji Representation: Nellie Starsmith Edermath Orchard 13 Action: patrolling, looking for adventurers, speaking to, observing, learning from, operations.
#     - Emoji Representation: Valerie Grinblade Alderleaf Farm 13 Action: Gathered robbers. Object: town square.
# Toblen Stonehill Lionshield Coster 14 I focused on doing business. I start by taking some orders from Phandalin who is searching for the missing Lionshield caravan. From this point, I start recruiting more merchants and collecting payment from merchants. I also look for any leads to help me better position my trading post. I make sure to provide proper assistance to those I meet and give them the best chance of success. I make sure to use the right tactics and resources to make sure I can keep the trade wars out of our trading post. I also try to make the most of my resources by utilizing them wisely to maximize profits.
# Daran Edermath Phandalin Town Square 14 I met Daran Edermath. I shared a apple cake.
# Linene Graywind The Sleeping Giant 14 Linnet searched the local area for buyers.
# Halia Thornton Shrine of Luck 14 I visited the temple and offered prayers to Tymora for good luck and prosperity.
# Qelline Alderleaf Townmaster’s Hall 14 Kelline and Conrad exchanged stories about their criminal pasts, likely revealing the origin of the orcs in town.
# Sister Garaele Alderleaf Farm 14 I left Alderleaf Farm today for an exploration of the surrounding area. I met with Sister Garaele and Valerie Grinblade to exchange information and gain insights into the Harpers current activities. (In the present tense: I went from Alderleaf Farms kitchen.)
# Harbin Wester Tresendar Manor 14 I interacting with Terrill Bloodscar.
# Terrill Bloodscar Tresendar Manor 14 Terrill Bloodscar planned to hide out in a secret room of Tresendar Manor until the next hour.
# Conrad Scarface Townmaster’s Hall 14 Conrad robbed the adventurers in the town the next hour.
# Nellie Starsmith Stonehill Inn 14 I slyly plan on stealing adventurers gold while they are in my care and use my connections to set up escorts to take them out. I will make sure all guards know that they are on a game, keep an eye on guards and be ready to chase them down at any moment. I will use my connections to make sure that all adventurers are lost, taken care of and that my escorts are always available when they find the gold.
# Valerie Grinblade Alderleaf Farm 14 I attempted to rob adventurers in the town square to gain an ultimate reward.
#     - Emoji Representation: Toblen Stonehill Lionshield Coster 14 Action, Object: focused on doing business, taking orders, finding leads, recruiting more merchants, collecting payment from merchants, looking for any possible advantages, using tactics and resources to keep trade wars out of trading post, using resources optimally for maximum profits.
#     - Emoji Representation: Daran Edermath Phandalin Town Square 14 Action: met Daran Edermath Object: apple cake
#     - Emoji Representation: Linene Graywind The Sleeping Giant 14 Action: searched Object: buyers.| Local area.
#     - Emoji Representation: Halia Thornton Shrine of Luck 14 action: object: bad luck: 0, good luck: 0, prosperity: 0
#     - Emoji Representation: Qelline Alderleaf Townmaster’s Hall 14 Kelline, Conrad, exchanged_stories, likely_revealing_the_origins_of_the_orcs, criminal_pasts.
#     - Emoji Representation: Sister Garaele Alderleaf Farm 14 I, left Alderleaf Farm, explored  , met Sister Garaele, Valerie Grinblade, gain insights into Harpers current activities   (present tense): I, go from Alderleaf Farm kitchen
#     - Emoji Representation: Harbin Wester Tresendar Manor 14 Interaction with: Terrill Bloodscar
#     - Emoji Representation: Terrill Bloodscar Tresendar Manor 14 Terrill Bloodscar Planned, Hid In A Secret Room of Tresendar Manor.
#     - Emoji Representation: Conrad Scarface Townmaster’s Hall 14 Conrad, robbed, adventurers
#     - Emoji Representation: Nellie Starsmith Stonehill Inn 14 [stealing, gold]
#     - Emoji Representation: Valerie Grinblade Alderleaf Farm 14 Action: attempted, Object: rob adventurers, location: town square, reward desired: ultimate
# Toblen Stonehill Townmaster’s Hall 15 I looked for bargains. I talked to Linene.
# Daran Edermath Tresendar Manor 15 I explored Tresendar Manor and took the opportunity to talk to Daran and Harbin. I also asked them about the various apple tree recipes they have found.
# Linene Graywind Townmaster’s Hall 15 I hunted for an orc, offering the reward.
# Halia Thornton The Sleeping Giant 15 Build Miners Exchange into dominant entity and expand its reach.
# Qelline Alderleaf Alderleaf Farm 15 Quantine joined the others in their conversations in the next hour.
# Sister Garaele Lionshield Coster 15 Sister Garaele investigated the nearby forest and looked for clues about the Harpers secret plan.
# Harbin Wester Tresendar Manor 15 I judged disputes and kept records. I ensured peace and justice.
# Terrill Bloodscar Shrine of Luck 15 Terrill Bloodscar went to the shrine, paid respects and put on a show of courage. He approached Toblen Stonehill, his intended target and the leader of the party. Then he moved to the adjacent ruins, looking for more adventurers.
# Conrad Scarface Alderleaf Farm 15 I robbed the adventurers in the town in the next hour.
# Nellie Starsmith Alderleaf Farm 15 Nell created a plan to make money off adventurers, with the help of other characters as needed, and to enlist Qelline Alderleaf to help find an appropriate target. This plan also included taking on Conrad Scarfaces ruffians when necessary.
# Valerie Grinblade Alderleaf Farm 15 In the next hour, I explored the surrounding area, hunted for adventurers, and captured the prize.
#     - Emoji Representation: Toblen Stonehill Townmaster’s Hall 15 I looked —-> bargains I talked —-> Linene.
#     - Emoji Representation: Daran Edermath Tresendar Manor 15 | Explored Tresendar Manor | Talked to Daran and Harbin | Asked them about the various apple tree recipes
#     - Emoji Representation: Linene Graywind Townmaster’s Hall 15 I_hunted_for_an_orc, offering_the_reward
#     - Emoji Representation: Halia Thornton The Sleeping Giant 15 Miners Exchange, Build, Expand..
#     - Emoji Representation: Qelline Alderleaf Alderleaf Farm 15 Action: Quantine joined Object: others
#     - Emoji Representation: Sister Garaele Lionshield Coster 15 Sister Garaele A. investigated [] [object] Nearby forest B. looked for clues about Harpers secret plan Sr. Garaele  [] [description]
#     - Emoji Representation: Harbin Wester Tresendar Manor 15 Executed judgment, maintained records. Promoted peace and justice.
#     - Emoji Representation: Terrill Bloodscar Shrine of Luck 15 Terrill Bloodscar, [Action], [Object]
#     - Emoji Representation: Conrad Scarface Alderleaf Farm 15 [I robbed, object, adventurer]
#     - Emoji Representation: Nellie Starsmith Alderleaf Farm 15 Nell Created a plan to make money off adventurers, with help of other characters as needed, to enlist Qelline Alderleaf to help find an appropriate target.
#     - Emoji Representation: Valerie Grinblade Alderleaf Farm 15 [Explored, hunted, captured]
# Toblen Stonehill Shrine of Luck 16 I visited the shrine and offered prayers to Tymora to get lucky. I looked for new resources and opportunities to make money. I also talked to Toplen and talked about what progress we have made thus far. Finally, I reminisced about our childhood and was grateful for the opportunities and people that had helped me reach my goals.
# Daran Edermath Tresendar Manor 16 I explored Tresendar Manor and its cellars to find a new recipe for apple trees.
# Linene Graywind Alderleaf Farm 16 I left town by 17:00 or thereabouts.
# Halia Thornton Townmaster’s Hall 16 I have gone to the townmaster’s hall. I have talked to Halia Thornton, who is now in the hall. I have explained my plans for the next hour.
# Qelline Alderleaf Tresendar Manor 16 Kelline spent the next hour chatting with the other players and exploring Tresendar Manor. She also aim to understand the mystery of the town, and its inhabitants.
# Sister Garaele The Sleeping Giant 16 I joined Grista and found out what the Harpers were up to.
# Harbin Wester Phandalin Miner's Exchange 16 I judged disputes and kept records at Phandalin Miners Exchange.
# Terrill Bloodscar Edermath Orchard 16 I awaited Toblen Stonehills arrival and began preparing for my robbery and murder mission.
# Conrad Scarface Townmaster’s Hall 16 Conrad Scarface robbed the adventurers from their journey across Wyvern Tor in the next hour. Afterward, he visited Halia Thornton at the Miner’s Exchange, where he sought to gain control of the merchant business.
# Nellie Starsmith Tresendar Manor 16 I plan to make a new friend, Qelline Alderleaf.
# Valerie Grinblade Alderleaf Farm 16 I planned to head to the town square to rob the adventurers there.
#     - Emoji Representation: Toblen Stonehill Shrine of Luck 16 Action: visit shrine, offer prayers to Tymora Object: luck -------> ::[Action:]] -------> :[Action:]
#     - Emoji Representation: Daran Edermath Tresendar Manor 16 a>Explored/a> b>Tresendar Manor/b> c>Cellars/c> d>Apple Trees./d>
#     - Emoji Representation: Linene Graywind Alderleaf Farm 16 Action: left town Object: 17:00 or thereabouts
#     - Emoji Representation: Halia Thornton Townmaster’s Hall 16 Action: Have gone to Townmaster’s Hall Action: Talked to Halia Thornton Action: Explained own plans for the next hour
#     - Emoji Representation: Qelline Alderleaf Tresendar Manor 16 Kelly visited Tresendar Manor, chatting with the other players; explored, aiming to understand the mystery of the town, and its inhabitants.
#     - Emoji Representation: Sister Garaele The Sleeping Giant 16 Joined [grista], Found [what the Harpers were up to]
#     - Emoji Representation: Harbin Wester Phandalin Miner's Exchange 16 Action: judged Object: disputes, records Employer: Phandalin Miners Exchange.
#     - Emoji Representation: Terrill Bloodscar Edermath Orchard 16 Action: I waited Toblen Stonehills arrival Object: my murder mission
#     - Emoji Representation: Conrad Scarface Townmaster’s Hall 16 Conrad Scarface robbed The adventurers, Wyvern Tor, Object Halia Thornton, Miners Exchange PRIMARY OCCUPATION gaining control of the merchant business.
#     - Emoji Representation: Nellie Starsmith Tresendar Manor 16 IPLANT, QELLINADELLEAF
#     - Emoji Representation: Valerie Grinblade Alderleaf Farm 16 Action: Planned to head to town square Object: Adventurers here.
# Toblen Stonehill Townmaster’s Hall 17 Toblen investigated and came up with a plan to make money for his trading post by avoiding Conrad Scarface. He intended to approach Sister Garaele to gain her help in tracking down the orcs and collecting evidence for his case. After gaining her trust and helping him gather evidence, Toblen will have gained more respect and will be able to start trading with her, earning more money for his trading post.
# Daran Edermath Tresendar Manor 17 Daran Edermath: I moved to the Redbrand workshop and hid in the shadows until I heard from Nellie Starsmith. I then asked her about the apple cake and why she came to Tresendar Manor. She tells me that someone from her family died in Phandalin and he is investigating the murders. I looked into their eyes and talked to one of the Redbrand ruffians and discussed possible answers to the murders. I explain mine and Nellies backgrounds and they start looking for possible solutions. Finally, at 18:00, I move to Tresendar Manor and start to search for the applestree recipe. It is difficult to get the recipe from the books, so they take over and make up some of their own.
# Linene Graywind Edermath Orchard 17 I headed to Alderleaf to find a buyer for an item I acquired for the trading post and bring my items back to E Dermath Orchard.
# Halia Thornton The Sleeping Giant 17 Gathered with the others, attempted to prevent Terrill Bloodscar from entering The Sleeping Giant, and moved to Halias home.
# Qelline Alderleaf The Sleeping Giant 17 Qelline moved to Tresendar Manor, where she continued chatting with new people. Qelline continued exploring the town, picking up clues from different people and landmarks. She heads back to The Sleeping Giant, where she meets Halia Thornton, before heading to the Miner’s Exchange for dinner. With dinner finished, Qelline was able to get dinner supplies at Stonehill Inn, and enjoy the night’s entertainment.
# Sister Garaele Townmaster’s Hall 17 I recollected evidence, talked to people, investigated, and unveil Harpers plan.
# Harbin Wester Shrine of Luck 17 I set up legal proceedings. I recorded records. I judged disputes. I oversaw activities.
# Terrill Bloodscar The Sleeping Giant 17 Terrill Bloodscar moved to Edermath Orchard. She spoke with Halia Thornton on her quest to rid the Adventurers as quickly as possible. The two exchanged a few words before Terrill left the house. Phandalin was left behind.
# Conrad Scarface Townmaster’s Hall 17 I assembled Redbrand ruffians to rob and kill adventurers in town.
# Nellie Starsmith Tresendar Manor 17 I proceeded westwards to Tresendar Manor, staying in the shadows. I encountered Daran Edermath, the half-elf living in a cottage beneath an apple orchard. I stood in Darans cottage and opened up to him about their plans to steal from adventurers. I explained to him that I was working on a plan to capture an adventurer in order to make money. On my way back to Tresendar Manor, I encountered a group of adventurers heading towards Tresendar.
# Valerie Grinblade Phandalin Town Square 17 In the next hour, I moved to Phandalin Town Square and began engaging in my plan of robbing adventurers. I aim to claim the prize by completing my robbery.
#     - Emoji Representation: Toblen Stonehill Townmaster’s Hall 17 Action: Investigated, Planted Action: Approaching, Inquire, Gain Trust, Collect Evidence, Act, Start Trading. Object: Sister Garaele.
#     - Emoji Representation: Daran Edermath Tresendar Manor 17 Daran Edermath, Nellie Starsmith, Apple Cake, Tresendar Manor.
#     - Emoji Representation: Linene Graywind Edermath Orchard 17 Action: headed to Alderleaf Object: item acquired for the trading post
#     - Emoji Representation: Halia Thornton The Sleeping Giant 17 Gathered, Prevented, Moved to Halias home.
#     - Emoji Representation: Qelline Alderleaf The Sleeping Giant 17 Qelline: move(to Tresendar Manor), chat(with new people), explore(the town, picking up clues, meeting (Halia Thornton), dinner(at Miners Exchange), dinner(at Stonehill Inn, enjoying the nights entertainment).
#     - Emoji Representation: Sister Garaele Townmaster’s Hall 17 Action -> Recollected evidence, talked to people, investigated, unveil Harpers plan.
#     - Emoji Representation: Harbin Wester Shrine of Luck 17 [action], [object]]
#     - Emoji Representation: Terrill Bloodscar The Sleeping Giant 17 Terrill Bloodscar ---> Moved Terrill Bloodscar ---> Spoke Halia Thornton ---> Object Terrill Bloodscar ---> Exchanging a few words Terrill Bloodscar ---> Object Terrill Bloodscar ---> Leaving Phandalin behind
#     - Emoji Representation: Conrad Scarface Townmaster’s Hall 17 Action: Arrange Redbrand ruffians Object: adventures in town
#     - Emoji Representation: Nellie Starsmith Tresendar Manor 17 Proceed westwards to Tresendar Manor, staying in shadows. Encountered Daran Edermath, elf living in cottage beneath apple orchard. Stuck in Darans cottage, opened up to him about their plans to steal, explained they were working on a plan to capture an adventurer to make money. Encountered group of adventurers travelling Tresendar.
#     - Emoji Representation: Valerie Grinblade Phandalin Town Square 17 Action: Moved to Phandalin Town Square Object: Adventurers Action: Begun robbing Adventurers Task: Claiming the prize Aim: completing robbing.
# Toblen Stonehill Edermath Orchard 18 I started work on the trading post tonight. I set up a business card and prepared samples. I chatted with customers to increase profits. I published marketing materials.
# Daran Edermath Tresendar Manor 18 Daran Edermath was motivated to investigate the Manor basement next hour in order to find a new recipe for apple trees.
# Linene Graywind Phandalin Miner's Exchange 18 Linene advertised for one of her goods at the miners exchange.
# Halia Thornton Alderleaf Farm 18 Halia Thornton: I aimed to increase the Miners Exchange in the town.
# Qelline Alderleaf Barthen's Provisions 18 I greet the people in the store, share news about my journey, and ask the staff for tips on how to make the most of your time in the store.
# Sister Garaele Phandalin Town Square 18 I set out to enumerate possible evidence to uncover the Harpers’ plan.
# Harbin Wester Shrine of Luck 18 I gathered evidence and informed the citizens on what happened while you were in Phandalin.
# Terrill Bloodscar Shrine of Luck 18 I am planning to ambush and rob adventurers in Shaine of Luck.
# Conrad Scarface Tresendar Manor 18 In the next hour, I attacked Daran and Nellie and stole their treasure.
# Nellie Starsmith Tresendar Manor 18 Nell Starsmith went to Tresendar Manor to prepare for the event. After talking to Daran Edermath, Conrad Scarface, and Nellie Starsmith, she determined how she wanted to take advantage of the opportunity. She set up traps and waited to see if any unfortunate adventurers wanted to come close to her targets. If so, they were taken out, either by offering them bribes or just forcing them to go and purchase the supplies she needed.
# Valerie Grinblade Phandalin Town Square 18 I stole from adventurers as part of my daily mission to be a ruffian and claim the town square for myself.
#     - Emoji Representation: Toblen Stonehill Edermath Orchard 18 Started work, Business card and samples prepared, Chated with customers, Published marketing materials.
#     - Emoji Representation: Daran Edermath Tresendar Manor 18 Daran Edermath, Motivated, investigate, Manor basement, next hour, find.
#     - Emoji Representation: Linene Graywind Phandalin Miner's Exchange 18 Linene - advertised - one of her goods at the miners exchange.
#     - Emoji Representation: Halia Thornton Alderleaf Farm 18 Action: increased; Object: the Miners Exchange
#     - Emoji Representation: Qelline Alderleaf Barthen's Provisions 18 Action: Greet people in store Object: News Object: Ask staff for tips Object: Tips
#     - Emoji Representation: Sister Garaele Phandalin Town Square 18 Action: Set out to enumerate evidence Object: uncover Harpers’ plan.
#     - Emoji Representation: Harbin Wester Shrine of Luck 18 Action: Gathered evidence, Inform citizens. Object: What happened while I was in Phandalin.
#     - Emoji Representation: Terrill Bloodscar Shrine of Luck 18 Action: ambush, rob Description: I am planning to ambush and rob adventurers in Shaine of Luck.
#     - Emoji Representation: Conrad Scarface Tresendar Manor 18 Action: Attacked Daran, Nellie Object: Treasure
#     - Emoji Representation: Nellie Starsmith Tresendar Manor 18 Action: Set traps (Object): Nellie Starsmith (Action): taken out (Object): unfortunate adventurers (Action): offering bribes (Object): forcing them to buy supplies (Object): gaining insight (Object): taking advantage (Object): taking out (Object): gaining advantage (Object): taking advantage (Object): taking advantage (Object): taking advantage (Object): taking gain (Object): taking advantage (Object): taking advantage (Action)
#     - Emoji Representation: Valerie Grinblade Phandalin Town Square 18 Action: Stealing Object: Adventurers Result: Be a ruffian, claim the town square for myself.
# Toblen Stonehill Shrine of Luck 19 Toblen spent the next hour surveying the shrine, gathering materials and resources, and talking to Nellie Starsmith.
# Daran Edermath Barthen's Provisions 19 Daran spent the next hour exploring Tresendar Manor and trying to uncover the identity of Nell. He brought whatever memories he has of apple cake with him to the meeting.
# Linene Graywind Phandalin Miner's Exchange 19 To sell goods, I reached out to potential buyers for one item, and built trust with the people in the exchange.
# Halia Thornton Phandalin Miner's Exchange 19 Hala Thornton: I organized a meeting with Linene Graywind and the other settlers to discuss plans for the next hour. I aimed to establish the Miners Exchange as the towns most reliable and trustworthy source of information and trading.
# Qelline Alderleaf Lionshield Coster 19 Celline talked to Sister Garaele about the importance of keeping peace in the town.
# Sister Garaele Lionshield Coster 19 I gathered information on Harpers. I engaged Qelline. I reported findings to Lord Gul. I followed up on leads.
# Harbin Wester Tresendar Manor 19 I began to collect evidence and set up trials. Terrill Bloodscar: Do some reconnaissance.
# Terrill Bloodscar Tresendar Manor 19 I retraced my steps. Talk to Harbin Wester. Steal secrets from Harbins records.
# Conrad Scarface Townmaster’s Hall 19 Conrad must have robbed the adventurers in the town.
# Nellie Starsmith Shrine of Luck 19 I robbed and killed any adventurers who ventured into the shrine.
# Valerie Grinblade The Sleeping Giant 19 I decided to meet with Grista in the next hour and try and collect evidence to prove that my plans worked.
#     - Emoji Representation: Toblen Stonehill Shrine of Luck 19 Action: Surveying, Gathering Materials, Talking to Nellie Starsmith
#     - Emoji Representation: Daran Edermath Barthen's Provisions 19 Daran > Exploring Tresendar Manor  trying to uncover Nell  remembering apple cake  attending meeting.
#     - Emoji Representation: Linene Graywind Phandalin Miner's Exchange 19 ACT: Reached out, PURCHASED, BUILT_TRUST
#     - Emoji Representation: Halia Thornton Phandalin Miner's Exchange 19 Hala Thornton, Meeting (doing), Settlers (Linene Graywind, other settlers), Planned, Establishment (Miners Exchange, towns most reliable and trustworthy source of information and trading).
#     - Emoji Representation: Qelline Alderleaf Lionshield Coster 19 Celline HAD talked to Sister Garaele ABOUT importance of keeping peace In the town FOR SET OF 5 (THE PAIR FROM THE SELECT>SELECTSELECT>)
#     - Emoji Representation: Sister Garaele Lionshield Coster 19 I collected information on Harpers •I engaged Qelline •I reported findings to Lord Gul •I followed up on leads
#     - Emoji Representation: Harbin Wester Tresendar Manor 19 Action: Do some reconnaissance. Object: accumulate evidence.
#     - Emoji Representation: Terrill Bloodscar Tresendar Manor 19 Action: retraced Step: Talk to Harbin Wester Object: secrets [String]
#     - Emoji Representation: Conrad Scarface Townmaster’s Hall 19 Conrad, Roamed. (action, robbed)
#     - Emoji Representation: Nellie Starsmith Shrine of Luck 19 Action, Object: Robbed, Killed
#     - Emoji Representation: Valerie Grinblade The Sleeping Giant 19 Action: met Grista, attempt to collect evidence, prove plans worked. Object: successful completion of my project.
# Toblen Stonehill Townmaster’s Hall 20 Toblen set out to make some money for his trading post, and visited Linenes to check in and ask how she was doing. He also confronted Conrad Scarface, who was also staying in the townmasters hall. After that, he made it back home with some more money in hand.
# Daran Edermath Tresendar Manor 20 I investigated Tresendar Manor and gathered info.
# Linene Graywind Alderleaf Farm 20 Linene spoke to Harbin Wester to find a buyer for one of her goods.
# Halia Thornton Phandalin Miner's Exchange 20 Hala Thornton looked to the future by further advancing the expansion of the Miners Exchange and ensuring its stability and prosperity over the coming months. She also plans to bolster the bonds of friendship within the community and seek out new opportunities.
# Qelline Alderleaf Townmaster’s Hall 20 Qelline met Toblen Stonehill and discussed the orc menace and their plan to take down the town leaders (Halflings and Brethren). She then headed to Lionshield Coster and looked for Conrad Scarface, who was talking to the other people on the rooftop about what happened before them and what actions they would take. Qelline then relocated back to the townmasters hall and chatted with Toblen, discussing the plan to take down the leaders, before following him to the entrance.
# Sister Garaele Tresendar Manor 20 I returned to Tresendar Manor and searched for evidence.
# Harbin Wester Alderleaf Farm 20 Haberin visited Linene Graywind to exchange gifts and discuss local events at home, possibly involving justice.
# Terrill Bloodscar Tresendar Manor 20 Terrill Bloodscar: I hunted down Nellie Starsmith. Meanwhile, Sister Garaele and Valerie Grinblade tried to stop me.
# Conrad Scarface Townmaster’s Hall 20 Conrad Scarface: I moved up to the tower and talked to Toblen Stonehill. We talked about the notice of orcs near Wyvern Tor. I made a plan to rob the adventurers.
# Nellie Starsmith Tresendar Manor 20 I attempted to capture and sell the remaining treasure from the merchant.
# Valerie Grinblade Tresendar Manor 20 Valerie Grinblade went to the town square and enlisted the help from the adventurers, in exchange for a share of the profits from the robbery, as well as establishing a relationship with the towns citizens and the local cleric to gain her revenge on Terrill and the Harpers.
#     - Emoji Representation: Toblen Stonehill Townmaster’s Hall 20 Action: set out, make money, visit Linenes, confront Conrad Scarface, go back home, with more money in hand.
#     - Emoji Representation: Daran Edermath Tresendar Manor 20 Investigated, Gathered info. (Action => Obj | Object)
#     - Emoji Representation: Linene Graywind Alderleaf Farm 20 Linene spoke Harbin Wester Finding buyer for object Goods
#     - Emoji Representation: Halia Thornton Phandalin Miner's Exchange 20 Hala Thornton - looked, Advancing [Miners Exchange] - expansion, Ensure [Stability, Prosperity], Bolster [Friendship] - within the community, Seek [New Opportunities].
#     - Emoji Representation: Qelline Alderleaf Townmaster’s Hall 20 Qelline met Toblen Stonehill, discussed orc menace, their plan to take down leaders (Halflings, Brethren); Qelline headed to Lionshield Coster, looked for Conrad Scarface, talking to others on the rooftop; Qelline chatted with Toblen, discussed take down the leaders, followed him to entrance.
#     - Emoji Representation: Sister Garaele Tresendar Manor 20 Return, Tresendar Manor, Search, Evidence.
#     - Emoji Representation: Harbin Wester Alderleaf Farm 20 Haberin visited [Linene Graywind], [gift, local], [interaction, justice]
#     - Emoji Representation: Terrill Bloodscar Tresendar Manor 20 action: hunted, object: Nellie Starsmith (contains hunted) while(contains sister).
#     - Emoji Representation: Conrad Scarface Townmaster’s Hall 20 Action: Move up, talk, notice, rob Objects: [orcs, wyvern tor, Conrad Scarface]
#     - Emoji Representation: Nellie Starsmith Tresendar Manor 20 Action: Capture, Object: Treasure
#     - Emoji Representation: Valerie Grinblade Tresendar Manor 20 Valerie Grinblade - Initiated - Got help from adventurers - Got robbery profit - Gained the revenge on Terrill - Set up relation with citizens - Found a clergyman
# Toblen Stonehill Tresendar Manor 21 I talked to Sister Garaele at 21:00 to get her opinion on the situation.
# Daran Edermath Edermath Orchard 21 I spent the next hour exploring the cottage and the orchard to find a new recipe for apple trees.
# Linene Graywind Alderleaf Farm 21 I sold one of my goods. I teleported to nearby towns, cities, or farms. I created content and interact with locals in order to meet and make connections with people. I plan my next day: [Meet villagers and discuss my goals. Reach out to vendors. Develop conversations. Establish relationships. Build trust and understanding. Engage in charitable acts.]
# Halia Thornton Lionshield Coster 21 I looked into the possibility of buying a nearby smithy and extending its capabilities to cater to the growing and changing needs of the people of Lionshield Coaster.
# Qelline Alderleaf The Sleeping Giant 21 I spoke to Grista and continued to chat. Meanwhile, I also moved to Lionshield Coster and looked forward to meeting new people.
# Sister Garaele Tresendar Manor 21 I stayed in Tresendar Manor, chatting to Toblen Stonehill, Nellie Starsmith, and Valerie Grinblade.
# Harbin Wester Townmaster’s Hall 21 He judged disputes, kept records, and posed as a ruffian. Terrill Bloodscar joined him and was a coward until he learned better.
# Terrill Bloodscar Townmaster’s Hall 21 I explained the importance of an orc, and offered to provide the transport to get us there. After the meeting, we traveled to the bar and had a good time.
# Conrad Scarface Shrine of Luck 21 Now, I had planned on leaving the Shrine of Luck behind and travelling to nearby towns, forming an alliance with them.
# Nellie Starsmith Tresendar Manor 21 I needed to troll the manor for treasure, identify criminals, and take advantage of opportunities.
# Valerie Grinblade Tresendar Manor 21 I searched for adventurers in the town square and robbed them. I also delved into the Redbrands’ underground facilities and attempted to locate Nellie.
#     - Emoji Representation: Toblen Stonehill Tresendar Manor 21 A, B: talked, Sister Garaele, opinion
#     - Emoji Representation: Daran Edermath Edermath Orchard 21 I - Explored the cottage - Orchard I - Found a new recipe for apple trees
#     - Emoji Representation: Linene Graywind Alderleaf Farm 21 Object: sale Action: teleported Object: nearby towns, cities, or farms Object: content Object: locals Object: build trust and understanding Object: engage in charitable acts
#     - Emoji Representation: Halia Thornton Lionshield Coster 21 I looked into Buying a nearby smithy Extending its capabilities to cater to the growing and changing needs of the people of Lionshield Coaster
#     - Emoji Representation: Qelline Alderleaf The Sleeping Giant 21 Action: spoke, continued to chat; Object: Lionshield Coster; Objective: meet new people.
#     - Emoji Representation: Sister Garaele Tresendar Manor 21 Action: Stayed in Tresendar Manor Description: Chatted to Toblen Stonehill, Nellie Starsmith, and Valerie Grinblade.
#     - Emoji Representation: Harbin Wester Townmaster’s Hall 21 -Judged disputes -Kept records -Posed as a ruffian -Joined Terrill Bloodscar -Became a coward
#     - Emoji Representation: Terrill Bloodscar Townmaster’s Hall 21 Action: Explain, Provide Transport, Travel to Bar, Enjoy Good Time.
#     - Emoji Representation: Conrad Scarface Shrine of Luck 21 Action Planned: Traveling to nearby towns, forming an alliance. Object(s): Shrine of Luck.
#     - Emoji Representation: Nellie Starsmith Tresendar Manor 21 troll  manor  treasure   identify  criminals   take  advantage  of  opportunities
#     - Emoji Representation: Valerie Grinblade Tresendar Manor 21 Action: Searched for adventurers in the town square, robbed Action: Delved into the Redbrands’ underground facilities, attempted to locate Nellie
# Toblen Stonehill Barthen's Provisions 22 I looked for customers and fulfilled orders. ### Final output:
# Daran Edermath Barthen's Provisions 22 Daran Edermath: [Recollection at Time 22:30: I then moved to Edermath Orchard.]
# Linene Graywind Tresendar Manor 22 Linn moved to Tresendar Manor and interacts with Sister Garaele and Terrill Bloodscar, trying to find a buyer for one of her goods.
# ...
# Qelline Alderleaf Tresendar Manor 24 I took a late night walk and attempted to chat with new people, and take in the town scene.
# Sister Garaele Tresendar Manor 24 I unveiled evidence to prove the Harpers plan. I also negotiated with the Harper ruffians to prevent the Harpers from escaping.
# Harbin Wester The Sleeping Giant 24 I judged disputes and kept records. I excluded Daran from the fun.
# Terrill Bloodscar Tresendar Manor 24 I planned to rob or murder any adventurers who ventured into Tresendar Manor in the next hour.
# Conrad Scarface Townmaster’s Hall 24 Conrad and Nellie discussed their upcoming raid. Conrad suggested going to Stonehill Inn again to seek out adventurers. Nellie suggested going to the nearby town of Wyvern Tor to investigate the orcs there. Conrad and Nellie decided to join forces and start planning their attack. They plan to ambush the orcs, take out a nearby bridge, and capture some captive orcs.
# Nellie Starsmith Townmaster’s Hall 24 Nell looked for adventurers to rob and kill in the next hour.
# Valerie Grinblade The Sleeping Giant 24 I prepared for the robbery mission. I recruited other Redbrand members. I disguised myself as a ruffian to avoid detection.
#     - Emoji Representation: Toblen Stonehill Tresendar Manor 24 Action: Look for work Object: money Action: Object: chest Object: items Action: Object: Qelline Object: interact more
#     - Emoji Representation: Daran Edermath The Sleeping Giant 24 Harbin, Valerie (Talked), Bottle of wine (Drank), Book of recipes (Found)
#     - Emoji Representation: Linene Graywind Shrine of Luck 24 Linene, MiningCommunity, FindABuyer (Object) for [item]
#     - Emoji Representation: Halia Thornton Phandalin Town Square 24 Action: Networking, Connecting; Object: Miners Exchange Mission.
#     - Emoji Representation: Qelline Alderleaf Tresendar Manor 24 Action: Late night walk, Object: new people, town scene
#     - Emoji Representation: Sister Garaele Tresendar Manor 24 Action[unveiled evidence], Object[ Harpers plan, escape]
#     - Emoji Representation: Harbin Wester The Sleeping Giant 24 Action: judged, kept Records. Object: Daran.
#     - Emoji Representation: Terrill Bloodscar Tresendar Manor 24 Action: Planned, Object: Adventurers, Tresendar Manor.
#     - Emoji Representation: Conrad Scarface Townmaster’s Hall 24 Action: discussing, raiding, finding adventurers, looking for orcs, ambush, bridge, capture captive orcs.
#     - Emoji Representation: Nellie Starsmith Townmaster’s Hall 24 Nell looked, for adventurers to rob and kill.
#     - Emoji Representation: Valerie Grinblade The Sleeping Giant 24 Action 1: Prepared Action 2: Raised funds Action 3: Object: Robbery
# Toblen Stonehill Stonehill Inn 25 I engaged in conversations with locals to try and make some money for my trading post.
# Daran Edermath Shrine of Luck 25 I talked to Linene and Valerie.
# Linene Graywind Shrine of Luck 25 Linene looked for a buyer for an item she had acquired for the trading post.
# Halia Thornton Phandalin Miner's Exchange 25 I moved to the Miner’s Exchange so I could meet and greet with the locals. I looked for opportunities to build the Miner’s Exchange. I also chatted with Conrad Scarface.
# Qelline Alderleaf Tresendar Manor 25 Kellin will talk to other characters, explore the Manor, and try to make meaningful connections with the locals.
# Sister Garaele Tresendar Manor 25 Sister Garaele and I searched Tresendar Manor and its cellars for any evidence that may help us uncover the Harpers secret plan.
# Harbin Wester Townmaster’s Hall 25 I judged disputes and kept records in the next hour.
# Terrill Bloodscar Tresendar Manor 25 Terrill hunted for adventurers in Tresendar Manor and planned their robbery.
# Conrad Scarface Phandalin Miner's Exchange 25 I set up a meeting with Conrad Scarface and Halia Thornton. I warned them of my plan to rob the adventurers. We talked over their targets and determined the best course of action.
# Nellie Starsmith The Sleeping Giant 25 I set up shop in The Sleeping Giant and made money off of the adventures I could find.
# Valerie Grinblade Shrine of Luck 25 Valerie made her way to the town square and robbed the adventurers. She also tried to talk to Daran Edermath and Linene Graywind about her plans to profit from their presence.
#     - Emoji Representation: Toblen Stonehill Stonehill Inn 25 Action: Engaged in Conversations Object: Locals, Money
#     - Emoji Representation: Daran Edermath Shrine of Luck 25 Action: talked Object: Linene, Valerie.
#     - Emoji Representation: Linene Graywind Shrine of Luck 25 Linene looked for a buyer, acquired for the trading post.
#     - Emoji Representation: Halia Thornton Phandalin Miner's Exchange 25 I, Moved, to, the, Miner’s Exchange, so, I could, meet, greet locals, build, construct, chatted, Conrad Scarface (Initialized), So, I, chatted.
#     - Emoji Representation: Qelline Alderleaf Tresendar Manor 25 Kellin: Talk, Explore, MakeMeaningfulConnections WithLocals.
#     - Emoji Representation: Sister Garaele Tresendar Manor 25 Descend, Search Trasendar Manor, Celleries; Descend, Find Harper
#     - Emoji Representation: Harbin Wester Townmaster’s Hall 25 [Judging disputes, Keeping records]
#     - Emoji Representation: Terrill Bloodscar Tresendar Manor 25 Terrill, Adventurers, Tresendar Manor | Planted|Action
#     - Emoji Representation: Conrad Scarface Phandalin Miner's Exchange 25 SET_UP_MEETING Conrad Scarface, Halia Thornton Warned them of my plan, discussed targets, determined best course of action
#     - Emoji Representation: Nellie Starsmith The Sleeping Giant 25 Action: set up shop Object: adventures
#     - Emoji Representation: Valerie Grinblade Shrine of Luck 25 Action: arrived, robbed, talk, gain profit (Valerie, adventurers, town square, adventurers, Daran Edermath, Linene Graywind), discuss (Valerie, town square, adventurers, Daran Edermath, Linene Graywind);
# Toblen Stonehill Townmaster’s Hall 26 I sought out the orcs near Wyvern Tor and reported them to the townmaster.
# Daran Edermath Barthen's Provisions 26 I talked to Kelline and Nell, explored Barthen’s, then looked for something special at the local tavern.
# Linene Graywind Phandalin Town Square 26 Linene opened an ice cream bar in town square to sell additional goods, achieving her goal of finding a buyer for an item.
# Halia Thornton Lionshield Coster 26 I should negotiate with Valerie to gain access to the cargo ship of the Lionshields.
# Qelline Alderleaf Barthen's Provisions 26 Qelline chatted with Daran Edermath in the next hour. She also explored the trading post and took pictures.
# Sister Garaele Tresendar Manor 26 I made inquiries, collected evidence, apprehended Harpers.
# Harbin Wester Tresendar Manor 26 I kept records, judged disputes, and did my job.
# Terrill Bloodscar Tresendar Manor 26 I worked inside Tresendar Manor. A group of Redbrand ruffians will be forming a line around Tresendar Manor, waiting to ambush and murder adventurers. I carefully plan my methods and use the equipment and skills I have available to execute my plan. If the Redbrand ruffians are successful in their mission, I may be tempted to join them, but I must be careful not to enrage the other Redbrand ruffians.
# Conrad Scarface Townmaster’s Hall 26 You robbed and killed the adventurers in the town.
# Nellie Starsmith Shrine of Luck 26 I met Nellie and the rogue. I planned to rob and murder adventurers in the next hour.
# Valerie Grinblade Lionshield Coster 26 Valerie grunted, turned to Halia and said, How am I supposed to rob adventurers?
#     - Emoji Representation: Toblen Stonehill Townmaster’s Hall 26 Action: sought Object: orcs near Wyvern Tor
#     - Emoji Representation: Daran Edermath Barthen's Provisions 26 Conversation, Barthen’s, Tavern
#     - Emoji Representation: Linene Graywind Phandalin Town Square 26 Linne (Action, Object)  (open ice cream bar, Object)  (find buyer for item, Objective)
#     - Emoji Representation: Halia Thornton Lionshield Coster 26 Action: Negotiate, Object: Access to the cargo ship of the Lionshields
#     - Emoji Representation: Qelline Alderleaf Barthen's Provisions 26 Qelline: Chatted Daran Edermath: in the next hour explored the trading post: took pictures.
#     - Emoji Representation: Sister Garaele Tresendar Manor 26 I - Interrogated -> Collected evidence I - Apprehended Harpers
#     - Emoji Representation: Harbin Wester Tresendar Manor 26 I Kept Records, Judged Disputes, Did My Job.
#     - Emoji Representation: Terrill Bloodscar Tresendar Manor 26 [Worked inside Tresendar Manor, Planned methods, employed equipment/skills, attempted to join Redbrand ruffians, Disregarded warnings, encountered other Redbrand ruffians]
#     - Emoji Representation: Conrad Scarface Townmaster’s Hall 26 Action, Object: robbed, killed.
#     - Emoji Representation: Nellie Starsmith Shrine of Luck 26 Action: rob, murder Object: adventurers
#     - Emoji Representation: Valerie Grinblade Lionshield Coster 26 Valerie grunted, turned, said, How am I supposed to rob adventurers?
# Toblen Stonehill Townmaster’s Hall 27 By opening a merchant post close to the townmasters hall and negotiating trading opportunities with other traders. He offered to help out Linene by providing advice on how to better exploit the orcs and other hostile entities nearby.
# Daran Edermath Tresendar Manor 27 Daran explored Tresendar Manor until 28:00.
# Linene Graywind Townmaster’s Hall 27 Linene discussed with Toblen Stonehill and Halia Thornton their experiences with dealing with orcs.
# Halia Thornton Townmaster’s Hall 27 Halia Thornton explored the town until she encountered an orc at the end of Wyvern Tor. She proceeded to the nearest settlement, Phandalin, and made contact with Toblen Stonehill. From there, she made arrangements to meet Linene Graywind and head back to Townmaster’s Hall to join her.
# Qelline Alderleaf Tresendar Manor 27 I chatted with Daran Edermath, Qelline Alderleaf, Sister Garaele, Harbin Wester, and explored Tresendar Manor.
# Sister Garaele Tresendar Manor 27 I investigated Tresendar Manor, uncovering the Harpers plan.
# Harbin Wester Tresendar Manor 27 Harbin Wester: I began my duty as Townmaster of Phandalin. Time to judge disputes and keep records.
# Terrill Bloodscar Edermath Orchard 27 Terrill Bloodscar prepared to attack the Apple Tree House at 7:00 PM.
# Conrad Scarface The Sleeping Giant 27 Conrad Scarface planned to disrupt the night with brazen robberies.
# Nellie Starsmith Shrine of Luck 27 Nellie attacked adventurers in the shrine.
# Valerie Grinblade Edermath Orchard 27 I made plans to rob in the town square at 28:00. I met Terrill Bloodscar and let him know my plan.
#     - Emoji Representation: Toblen Stonehill Townmaster’s Hall 27 Action: opening merchant post Object: orcs, hostile entities
#     - Emoji Representation: Daran Edermath Tresendar Manor 27 Daran: Explored Tresendar Manor EXP: 28:00.
#     - Emoji Representation: Linene Graywind Townmaster’s Hall 27 Linene A/P Toblen Stonehill/Halia Thornton discuss their experiences w/ dealing with orcs.
#     - Emoji Representation: Halia Thornton Townmaster’s Hall 27 | Action | Object | Adventure | |------|---------------------- | | - | Explored | | | Attached | | Encounter | | | Pandalin | | | | Reached | | | || || | | || | | | | || | || | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | |
#     - Emoji Representation: Qelline Alderleaf Tresendar Manor 27 -> CHATTED => TALKED TO Daran Edermath => Qelline Alderleaf => Sister Garaele => Harbin Wester => Explored Tresendar Manor
#     - Emoji Representation: Sister Garaele Tresendar Manor 27 Action: Investigated Tresendar Manor Object: Harpers plan
#     - Emoji Representation: Harbin Wester Tresendar Manor 27 Action: begin, Object: judge, Object: records.
#     - Emoji Representation: Terrill Bloodscar Edermath Orchard 27 Terrill Bloodscar prepared TO attack Apple Tree House AT 7:00 PM.
#     - Emoji Representation: Conrad Scarface The Sleeping Giant 27 Conrad Scarface, Action, Planned to disrupt the night with brazen robberies.
#     - Emoji Representation: Nellie Starsmith Shrine of Luck 27 [Action, Object]
#     - Emoji Representation: Valerie Grinblade Edermath Orchard 27 rob, town_square, 28:00; met, Terrill Bloodscar; let, him know.
# Toblen Stonehill Townmaster’s Hall 28 I plan to go to the orc-infested field near Wyvern Tor. I will hire the braves assigned to the mission such as Corbett, Lezli, and Rosie to find my target and bring them down to the townmaster’s hall, if necessary. If they fail me I will try my best to locate Nellie.
# Daran Edermath Tresendar Manor 28 I continued exploring Tresendar Manor and looked for new recipes for apple trees. I am looking for recipes that will make apple trees more resilient against the Redbrands and make them more delicious. I am also looking to uncover the origin of the Redbrands base in Phandalin and see if they are still willing to share their recipe with me.
# Linene Graywind Alderleaf Farm 28 Linene looked for customers for her goods at the trading post.
# Halia Thornton Edermath Orchard 28 I aimed to continue building the Miners Exchange and expand its reach.
# Qelline Alderleaf Tresendar Manor 28 Qelline continued her exploration of Tresendar Manor today by interacting with Daran Edermath and Qelline Alderleaf.
# Sister Garaele Shrine of Luck 28 I join Sister Garaele and two other Harper agents (sister, Terrill) at the Shrine of Luck and start talking to them to learn more about what the Harpers are up to. We have a lengthy conversation uncovering some of their past plans.
# Harbin Wester The Sleeping Giant 28 I resolved minor disputes and kept records. I also remained loyal to Grista and hoped they doesnt hurt me while Im here.
# Terrill Bloodscar Shrine of Luck 28 Terrill Bloodscar robbed and killed adventurers in the next hour.
# Conrad Scarface Shrine of Luck 28 I robbed the adventurers in the Shrine of Luck.
# Nellie Starsmith Townmaster’s Hall 28 I went to Townmasters Hall and confronted Toblen about how they could both make money off the adventurers.
# Valerie Grinblade Lionshield Coster 28 taken revenge on the adventurers.
#     - Emoji Representation: Toblen Stonehill Townmaster’s Hall 28 Action: Go to the orc-infested field near Wyvern Tor, Hire braves assignees, Attempt to locate Nellie (in case they fail), Attempt to locate Nellie (in case they succeed).
#     - Emoji Representation: Daran Edermath Tresendar Manor 28 Exploring Tresendar Manor, looking for new recipes for apple trees. Trying to find recipes stronger against the Redbrands, more delicious and uncovering the origin of the Redbrands base in Phandalin. Looking to see if Redbrands are still willing to share their recipe.
#     - Emoji Representation: Linene Graywind Alderleaf Farm 28 Linene looked for customers, goods, at the trading post.
#     - Emoji Representation: Halia Thornton Edermath Orchard 28 Action: Building, Object: Miners Exchange
#     - Emoji Representation: Qelline Alderleaf Tresendar Manor 28 A). continued B). Tresendar Manor A) b) with Daran Edermath C) Qelline Alderleaf o) d) Tresendar Manor
#     - Emoji Representation: Sister Garaele Shrine of Luck 28 Action: join Sister Garaele, Harper Agents (Sister, Terrill), at Shrine of Luck Object: Harper Upcoming Action: uncovering Their Past Planned Action: uncover (several) past plans
#     - Emoji Representation: Harbin Wester The Sleeping Giant 28 [Resolved minor disputes, Kept records, Remained loyal to Grista, Hopeful that they does not hurt me]
#     - Emoji Representation: Terrill Bloodscar Shrine of Luck 28 Terrill Bloodscar robbed, killed adventurers at +-(1 hour).
#     - Emoji Representation: Conrad Scarface Shrine of Luck 28 Action: Robbed Object: Adventurers
#     - Emoji Representation: Nellie Starsmith Townmaster’s Hall 28 Action: went to Townmasters Hall, confronted Toblen Object: money
#     - Emoji Representation: Valerie Grinblade Lionshield Coster 28 Action: taken revenge, Object: adventurers
